# %%
# import necessary packages 
import cv2 
import matplotlib.pyplot as plt 
import numpy as np # to create zeros matrix (see explanation below)
import matplotlib.pyplot as plt # to plot histogram as well as image itself 
from skimage import io # to read an image

# %%
# load image 
imageObj = cv2.imread('/Users/tigrangaplanyan/Downloads/ImageJ/Midterm_Project/L033/L033_p1.jpg') 
# to avoid grid lines 
plt.axis("off") 
plt.title("Original Image") 
plt.imshow(cv2.cvtColor(imageObj, cv2.COLOR_BGR2RGB)) 
plt.show() 
  
# Get RGB data from image 
blue_color = cv2.calcHist([imageObj], [0], None, [256], [0, 256]) 
red_color = cv2.calcHist([imageObj], [1], None, [256], [0, 256]) 
green_color = cv2.calcHist([imageObj], [2], None, [256], [0, 256]) 
  
# Separate Histograms for each color 
plt.subplot(3, 1, 1) 
plt.title("histogram of Blue") 
plt.hist(blue_color, color="blue") 
  
plt.subplot(3, 1, 2) 
plt.title("histogram of Green") 
plt.hist(green_color, color="green") 
  
plt.subplot(3, 1, 3) 
plt.title("histogram of Red") 
plt.hist(red_color, color="red") 
  
# for clear view 
plt.tight_layout() 
plt.show() 
  
# combined histogram 
plt.title("Histogram of all RGB Colors") 
plt.hist(blue_color, color="blue") 
plt.hist(green_color, color="green") 
plt.hist(red_color, color="red") 
plt.show()

# %%
img = cv2.imread('/Users/tigrangaplanyan/Downloads/ImageJ/Midterm_Project/L033/L033_p1.jpg',0) 
  
# find frequency of pixels in range 0-255 
histr = cv2.calcHist([img],[0],None,[256],[0,256]) 
  
# show the plotting graph of an image 
plt.plot(histr) 
plt.show()

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('/Users/tigrangaplanyan/Downloads/ImageJ/Midterm_Project/L033/L033_p1.jpg', cv.IMREAD_GRAYSCALE)
assert img is not None, "file could not be read, check with os.path.exists()"
img = cv.medianBlur(img,5)
ret,th1 = cv.threshold(img,127,255,cv.THRESH_BINARY)
th2 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_MEAN_C,\
            cv.THRESH_BINARY,11,2)
th3 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv.THRESH_BINARY,11,2)
titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]
for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('/Users/tigrangaplanyan/Downloads/ImageJ/Midterm_Project/L033/L033_p1.jpg')

# Calculate RGB histogram
colors = ('b', 'g', 'r')
for i, col in enumerate(colors):
    hist = cv2.calcHist([image], [i], None, [256], [0, 256])
    plt.plot(hist, color=col)
    plt.xlim([0, 256])

plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.title('RGB Histogram')
plt.show()

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Calculate Grayscale histogram
hist = cv2.calcHist([gray_image], [0], None, [256], [0, 256])
plt.plot(hist, color='k')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.title('Grayscale Histogram')
plt.show()

# %%
# Convert the grayscale image to binary using adaptive thresholding
binary_image = cv2.adaptiveThreshold(gray_image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 11, 10)

# Display the binary image
cv2.imshow('Binary Image', binary_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Load the image
image = cv2.imread('/Users/tigrangaplanyan/Downloads/ImageJ/Midterm_Project/L033/L033_p1.jpg')

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply adaptive thresholding to get a binary image
binary_image = cv2.adaptiveThreshold(gray_image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 11, 10)

# Perform morphological operations (erosion and dilation) to further remove noise
kernel = np.ones((5, 5), np.uint8)
binary_image = cv2.erode(binary_image, kernel, iterations=1)
binary_image = cv2.dilate(binary_image, kernel, iterations=1)

# Invert the binary image to prepare for text removal
binary_image = cv2.bitwise_not(binary_image)

# Apply the mask to remove text from the original image
result = cv2.bitwise_and(image, image, mask=binary_image)

# Display the result
cv2.imshow('Image with Removed Text', result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
# Define the lower and upper bounds for red color
lower_red = np.array([0, 0, 150])
upper_red = np.array([100, 100, 255])

# Create a mask to filter red shades
mask = cv2.inRange(image, lower_red, upper_red)
result = cv2.bitwise_and(image, image, mask=mask)

# Display the result with removed red marks
cv2.imshow('Result with Removed Red Marks', result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
/Users/tigrangaplanyan/Downloads/ImageJ/Midterm_Project/L033/L033_p1.jpg

# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image

# Read an image
image = Image.open('/Users/tigrangaplanyan/Downloads/ImageJ/Midterm_Project/L033/L033_p1.jpg')  # Replace 'path/to/your/image.jpg' with the path to your image

# Show the image
image.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/Users/tigrangaplanyan/Downloads/ImageJ/Midterm_Project/L033/L033_p1.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

h, w, c = img.shape

if w > 1000:
    
    new_w = 1000
    ar = w/h
    new_h = int(new_w/ar)
    
    img = cv2.resize(img, (new_w, new_h), interpolation = cv2.INTER_AREA)
plt.imshow(img);

# %%
def thresholding(image):
    img_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    ret,thresh = cv2.threshold(img_gray,80,255,cv2.THRESH_BINARY_INV)
    plt.imshow(thresh, cmap='gray')
    return thresh

thresh_img = thresholding(img);

# %%
#dilation
kernel = np.ones((3,85), np.uint8)
dilated = cv2.dilate(thresh_img, kernel, iterations = 1)
plt.imshow(dilated, cmap='gray');

# %%
(contours, heirarchy) = cv2.findContours(dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
sorted_contours_lines = sorted(contours, key = lambda ctr : cv2.boundingRect(ctr)[1]) # (x, y, w, h)

# %%
img2 = img.copy()

for ctr in sorted_contours_lines:
    
    x,y,w,h = cv2.boundingRect(ctr)
    cv2.rectangle(img2, (x,y), (x+w, y+h), (40, 100, 250), 2)
    
plt.imshow(img2);

# %%
#dilation
kernel = np.ones((3,15), np.uint8)
dilated2 = cv2.dilate(thresh_img, kernel, iterations = 1)
plt.imshow(dilated2, cmap='gray');

# %%
img3 = img.copy()
words_list = []

for line in sorted_contours_lines:
    
    # roi of each line
    x, y, w, h = cv2.boundingRect(line)
    roi_line = dilated2[y:y+w, x:x+w]
    
    # draw contours on each word
    (cnt, heirarchy) = cv2.findContours(roi_line.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    sorted_contour_words = sorted(cnt, key=lambda cntr : cv2.boundingRect(cntr)[0])
    
    for word in sorted_contour_words:
        
        if cv2.contourArea(word) < 400:
            continue
        
        x2, y2, w2, h2 = cv2.boundingRect(word)
        words_list.append([x+x2, y+y2, x+x2+w2, y+y2+h2])
        cv2.rectangle(img3, (x+x2, y+y2), (x+x2+w2, y+y2+h2), (255,255,100),2)
        
plt.imshow(img3);
